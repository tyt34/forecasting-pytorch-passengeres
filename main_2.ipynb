# %% [markdown]
# <a href="https://colab.research.google.com/github/dlmacedo/starter-academic/blob/master/content/courses/deeplearning/notebooks/pytorch/Time_Series_Prediction_with_LSTM_Using_PyTorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Time Series Prediction with LSTM Using PyTorch
#
# This kernel is based on *datasets* from
#
# [Time Series Forecasting with the Long Short-Term Memory Network in Python](https://machinelearningmastery.com/time-series-forecasting-long-short-term-memory-network-python/)
#
# [Time Series Prediction with LSTM Recurrent Neural Networks in Python with Keras](https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/)

# %% [markdown]
# ## Download Dataset

# %%
#!wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/shampoo.csv

# %%
# в данном проекте уже скачан данный файл
#!wget https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv

# %% [markdown]
# ## Library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torch.nn as nn
from torch.autograd import Variable
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Data Plot

# %%
training_set = pd.read_csv('airline-passengers.csv')
#training_set = pd.read_csv('shampoo.csv')

training_set = training_set.iloc[:,1:2].values

#plt.plot(training_set, label = 'Shampoo Sales Data')
plt.plot(training_set, label = 'Airline Passangers Data')
plt.show()

# %% [markdown]
# ## Dataloading

# %%
def sliding_windows(data, seq_length):
    x = []
    y = []

    for i in range(len(data)-seq_length-1):
        _x = data[i:(i+seq_length)]
        _y = data[i+seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

sc = MinMaxScaler()
training_data = sc.fit_transform(training_set)

""" 
In originals: 
seq_length = 4
"""
seq_length = 60
x, y = sliding_windows(training_data, seq_length)

""" 
In originals:
train_size = int(len(y) * 0.67)
"""
train_size = int(len(y) * 0.8)
test_size = len(y) - train_size

dataX = Variable(torch.Tensor(np.array(x)))
dataY = Variable(torch.Tensor(np.array(y)))

trainX = Variable(torch.Tensor(np.array(x[0:train_size])))
trainY = Variable(torch.Tensor(np.array(y[0:train_size])))

testX = Variable(torch.Tensor(np.array(x[train_size:len(x)])))
testY = Variable(torch.Tensor(np.array(y[train_size:len(y)])))

# %% [markdown]
# ## Model

# %%
class LSTM(nn.Module):

    def __init__(self, num_classes, input_size, hidden_size, num_layers):
        super(LSTM, self).__init__()
        print('num cl: ', num_classes)
        print('num l: ', num_layers)
        print('in size: ', input_size)
        print('hi size: ', hidden_size)
        self.num_classes = num_classes
        self.num_layers = num_layers
        self.input_size = input_size
        self.hidden_size = hidden_size
        self.seq_length = seq_length
        
        self.lstm = nn.LSTM(
          input_size=input_size, 
          hidden_size=hidden_size,
          num_layers=num_layers, 
          batch_first=True
        )
        
        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        """ 
        Эта строка инициализирует скрытое состояние LSTM модели. 
        И создает тензор размерности 
        (
          self.num_layers, 
          x.size(0), 
          self.hidden_size
        )
        и заполняет его нулям
        """
        h_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        # print(' h_0: ', h_0)

        c_0 = Variable(torch.zeros(
            self.num_layers, x.size(0), self.hidden_size))
        
        # Propagate input through LSTM
        ula, (h_out, _) = self.lstm(x, (h_0, c_0))
        
        h_out = h_out.view(-1, self.hidden_size)
        
        out = self.fc(h_out)
        
        return out

# %% [markdown]
# ## Training

# %%
num_epochs = 2000
learning_rate = 0.01

""" 
In originals: 

num_classes = 1
num_layers = 1
input_size = 1
hidden_size = 2
"""
num_classes = 1
num_layers = 1
input_size = 1
hidden_size = 2

lstm = LSTM(num_classes, input_size, hidden_size, num_layers)

criterion = torch.nn.MSELoss()    # mean-squared error for regression
optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#optimizer = torch.optim.SGD(lstm.parameters(), lr=learning_rate)

# Train the model
for epoch in range(num_epochs):
    outputs = lstm(trainX)
    optimizer.zero_grad()
    
    # obtain the loss function
    loss = criterion(outputs, trainY)
    
    loss.backward()
    
    optimizer.step()
    if epoch % 100 == 0:
      print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
# Out:
# num cl:  1
# num l:  1
# in size:  1
# hi size:  2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 17
#      14 input_size = 1
#      15 hidden_size = 2
# ---> 17 lstm = LSTM(num_classes, input_size, hidden_size, num_layers)
#      19 criterion = torch.nn.MSELoss()    # mean-squared error for regression
#      20 optimizer = torch.optim.Adam(lstm.parameters(), lr=learning_rate)
#
# Cell In[7], line 15, in LSTM.__init__(self, num_classes, input_size, hidden_size, num_layers)
#      12 self.hidden_size = hidden_size
#      13 self.seq_length = seq_length
# ---> 15 self.lstm = nn.LSTM(
#      16   nput_size=input_size,
#      17   hidden_size=hidden_size,
#      18   num_layers=num_layers,
#      19   batch_first=True
#      20 )
#      22 self.fc = nn.Linear(hidden_size, num_classes)
#
# File ~/.local/lib/python3.8/site-packages/torch/nn/modules/rnn.py:711, in LSTM.__init__(self, *args, **kwargs)
#     710 def __init__(self, *args, **kwargs):
# --> 711     super().__init__('LSTM', *args, **kwargs)
#
# TypeError: __init__() got an unexpected keyword argument 'nput_size'

# %% [markdown]
# ## Testing for Airplane Passengers Dataset

# %%
lstm.eval()
train_predict = lstm(dataX)

data_predict = train_predict.data.numpy()
dataY_plot = dataY.data.numpy()

data_predict = sc.inverse_transform(data_predict)
dataY_plot = sc.inverse_transform(dataY_plot)

plt.axvline(x=train_size, c='r', linestyle='--')

plt.plot(dataY_plot)
plt.plot(data_predict)
plt.suptitle('Time-Series Prediction')
plt.show()
